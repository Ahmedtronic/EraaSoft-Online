# %%
# stack , queue , priority queue

# %%
import queue

# %%
from queue import PriorityQueue

# %%
from queue import *

# %%
import ahmedhafez

# %%
ahmedhafez.AI_GOAT
# Out:
# 'Ahmed Hafez'

# %%
from ahmedhafez import print_instructor
print_instructor()
# Out:
# I'm the best Instructor in the world

# %%
import queue
pq = queue.PriorityQueue()

# %%
from queue import PriorityQueue
pq = PriorityQueue()

# %%
from queue import Queue

# %%
myq = Queue()

# %%
type(myq)
# Out:
# queue.Queue

# %%
myq.qsize()
# Out:
# 0

# %%
myq.empty()
# Out:
# True

# %%
myq.put("Ahmed")
myq.put(2)
myq.put(True)
myq.put(6)
myq.put([2,3,4,5,])

# %%
myq.qsize()
# Out:
# 5

# %%
myq.get()
# Out:
# 'Ahmed'

# %%
myq.get()
# Out:
# 2

# %%
myq.empty()
# Out:
# False

# %%
while myq.qsize() != 0 : 
    print(myq.get())
# Out:
# True
# 6
# [2, 3, 4, 5]

# %%
myq.qsize()
# Out:
# 0

# %%
pq = PriorityQueue()
pq.qsize()
# Out:
# 0

# %%
pq.put(2)
pq.put(2.3)
pq.put(True)
pq.put(11)
pq.put(23)
pq.put(False)
pq.put(1)
pq.put(90)

# %%
pq.qsize()
# Out:
# 8

# %%
pq.get()
# Out:
# False

# %%
pq.get()
# Out:
# True

# %%
pq.get()
# Out:
# 1

# %%
while pq.qsize() !=0 : 
    print(pq.get())
# Out:
# 2
# 2.3
# 11
# 23
# 90

# %%
-False
# Out:
# 0

# %%
pq.put(-2)
pq.put(-2.3)
pq.put(-True)
pq.put(-11)
pq.put(-23)
pq.put(-False)
pq.put(-1)
pq.put(-90)

# %%
while pq.qsize() !=0 :
    print(pq.get() * -1 )
# Out:
# 90
# 23
# 11
# 2.3
# 2
# 1
# 1
# 0

# %%
from queue import LifoQueue

# %%
from queue import LifoQueue as stack

# %%
s = stack( )

# %%
s.put(2)
s.put(12)
s.put(9)
s.put(2.3)
s.put("Ahmed")
s.put([2,4,32])
s.put(10)

# %%
s.get()
# Out:
# 10

# %%
while s.empty() == False :
    print(s.get())
# Out:
# [2, 4, 32]
# Ahmed
# 2.3
# 9
# 12
# 2
