# %% [markdown]
# <center> <h1> Introduction to AI </h1> Optimization <br> Generalization </center>

# %% [markdown]
#
# 80% Data <br>
#  - 90% Data Cleaning ( Redundency, Missing Values, Inconsistancy ) <br>
#  - 10% Data Analysis
#
# 20% Modeling ( machine learning & deep learning ) <br>
#
#
#
# **AI Pipeline:**
#
# 1. Verify
# 2. Data Gathering ( Data Collection , Data Accquring )
# 3. Data Preprocessing ( Clean, Organization, Scaling, Normalization, Reshape  )
# 4. Feature Engineering & Analysis
# 5. Model Selection ( choose best algorithm )
# 6. Fit data into the model
# 7. Train
# 8. Test
# 81. Documentation
# 9. Integrate & Deploy
# 10. Release
# 11. Monitor
# 12. Maintain ( Retrain, Add new features, Create (a) new model(s) )

# %% [markdown]
# **Data Collection Methods:**
#
# 1. Available On site ( Direct Access )
# 2. Available Online ( Free ) : Download
# 3. Available Online ( Not for free ) : Buy
# 4. Available ( not for sale ) :  Request
# 5. Not Available but exists : ( Scrapping )
# 5. Doesn't exist : ( Create )
#
# **How to create data:** <br>
# 1- Surveys / Forms <br>
# 2- Data Entery ( i.e. Sales, Customer Service )  <br>
# 3- Incentives <br>
# 4- Generative AI <br>
# 5- Synthetic Data
#
# **Websites to get free data:** <br>
#
# 1. Google Datasets ( https://datasetsearch.research.google.com )
# 2. Kaggle ( https://www.kaggle.com/datasets )
# 3. Data.world ( https://data.world/datasets/open-data )
# 4. Huggingface ( https://huggingface.co/datasets )
# 5. Academic Torrents (https://academictorrents.com/browse.php)
# 6. Roboflow : ( https://universe.roboflow.com/ )

# %% [markdown]
# ### Buy Dataset :
# 1. Data & Sons: https://www.dataandsons.com/

# %% [markdown]
# ### How These Data Are Collected ?  :
# - Note: Big Companies Collect & Sell your data, How ? Tracking...
# - You can block tracking
# - See ghostry : https://www.ghostery.com/

# %% [markdown]
# **Web Scrapping:**
#
# 1- Beautifulsoup <br>
# 2- Requests ( api --> request )  <br>
# 3- Selenium ( automatic scrapping ) <br>
# 4- Cron jobs: ( Automatic method ) in linux , Task Schedular in Windows <br>
#
#
# How to install a package in Python:
# 1. pip
# 2. conda
# 3. uv
# 4. mamba
#
#
# **Task :** What is RPA & its tools?
#
# what is a library ? a module ? <br>
# --> import re ( use regular expression ) <br>
# --> print("Ahmed")

# %%
# method 1 :! pip install requests  or conda install anaconda::beautifulsoup4
# method 2 : start menu --> open anaconda prompt , paste the installation line

# %%
! pip install beautifulsoup4

# %% [markdown]
# **Web:** <br>
# * frontend : Design  ( html : hyper text markup langauage,css , js ) <br>
# * backend : Database, server and operations
#
#
# **note** : we can now write python directly into html
# <br>
# "<"py-script> python code "<"/py-script> <br>
# __check :__ https://www.javatpoint.com/pyscript <br>
# __check :__ [reactpy](https://github.com/reactive-python/reactpy)

# %% [markdown]
# ### Scrapping Tools:

# %% [markdown]
# - https://apify.com/
# - https://www.parsehub.com/
# - https://www.octoparse.com/blog/9-free-web-scrapers-that-you-cannot-miss
