# %%
class Stack:
    def __init__(self):
        self.items = []

    def is_empty(self):
        return len(self.items) == 0

    def push(self, item):
        self.items.append(item)

    def pop(self):
        if not self.is_empty():
            return self.items.pop()

    def peek(self):
        if not self.is_empty():
            return self.items[-1]

    def size(self):
        return len(self.items)

# Example usage:
stack = Stack()
stack.push(1)
stack.push(2)
stack.push(3)
print(stack.pop())  # Output: 3
# Out:
# 3

# %%
import queue 
stack = queue.LifoQueue()

# %%
from collections import deque

class Queue:
    def __init__(self):
        self.items = deque()

    def is_empty(self):
        return len(self.items) == 0

    def enqueue(self, item):
        self.items.append(item)

    def dequeue(self):
        if not self.is_empty():
            return self.items.popleft()

    def size(self):
        return len(self.items)

# Example usage:
queue = Queue()
queue.enqueue(1)
queue.enqueue(2)
queue.enqueue(3)
print(queue.dequeue())  # Output: 1
# Out:
# 1

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def append(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def display(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# Example usage:
linked_list = LinkedList()
linked_list.append(1)
linked_list.append(2)
linked_list.append(3)
linked_list.display()  # Output: 1 -> 2 -> 3 -> None
# Out:
# 1 -> 2 -> 3 -> None

# %%
import heapq

class PriorityQueue:
    def __init__(self):
        self.heap = []

    def is_empty(self):
        return len(self.heap) == 0

    def push(self, item, priority):
        heapq.heappush(self.heap, (priority, item))

    def pop(self):
        if not self.is_empty():
            return heapq.heappop(self.heap)[1]

    def peek(self):
        if not self.is_empty():
            return self.heap[0][1]

    def size(self):
        return len(self.heap)

# Example usage:
priority_queue = PriorityQueue()
priority_queue.push("Task 1", 3)
priority_queue.push("Task 2", 1)
priority_queue.push("Task 3", 2)
print(priority_queue.pop())  # Output: Task 2
# Out:
# Task 2

# %%
class Graph:
    def __init__(self):
        self.graph = {}

    def add_vertex(self, vertex):
        if vertex not in self.graph:
            self.graph[vertex] = []

    def add_edge(self, start, end):
        self.add_vertex(start)
        self.add_vertex(end)
        self.graph[start].append(end)

    def display(self):
        for vertex in self.graph:
            print(f"{vertex}: {', '.join(map(str, self.graph[vertex]))}")

# Example usage:
custom_graph = Graph()
custom_graph.add_edge(1, 2)
custom_graph.add_edge(1, 3)
custom_graph.add_edge(2, 3)
custom_graph.add_edge(3, 4)
custom_graph.display()
# Out:
# 1: 2, 3
# 2: 3
# 3: 4
# 4:

# %%
import networkx as nx

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
graph = nx.DiGraph()

# Add edges
graph.add_edge(1, 2)
graph.add_edge(2, 1)
graph.add_edge(1, 3)
graph.add_edge(2, 3)
graph.add_edge(3, 4)

# Draw the graph (optional)
nx.draw(graph, with_labels=True, font_weight='bold', arrows=True,  node_size=800)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 15
#      12 graph.add_edge(3, 4)
#      14 # Draw the graph (optional)
# ---> 15 nx.draw(graph, with_labels=True, font_weight='bold', arrows=True,  node_size=800)
#      16 plt.show()
#
# File /opt/miniconda3/envs/base_new/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py:113, in draw(G, pos, ax, **kwds)
#     111 cf.set_facecolor("w")
#     112 if ax is None:
# --> 113     if cf._axstack() is None:
#     114         ax = cf.add_axes((0, 0, 1, 1))
#     115     else:
#
# TypeError: '_AxesStack' object is not callable

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a graph
graph = nx.Graph()

# Add edges
graph.add_edge(1, 2)
graph.add_edge(1, 3)
graph.add_edge(2, 3)
graph.add_edge(3, 4)

# Draw the graph (optional)
nx.draw(graph, with_labels=True, font_weight='bold', arrows=True,  node_size=800)
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a weighted graph
G = nx.DiGraph()
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'C', weight=2)
G.add_edge('C', 'D', weight=1)
G.add_edge('D', 'C', weight=8)
G.add_edge('D', 'E', weight=3)
G.add_edge('E', 'A', weight=5)

# Draw the graph with weights
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a weighted graph
G = nx.Graph()
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'C', weight=2)
G.add_edge('C', 'D', weight=1)
G.add_edge('D', 'E', weight=3)
G.add_edge('E', 'A', weight=5)

# Draw the graph with weights
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=500)
labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=labels)

plt.show()

# %%
G = nx.Graph()
G.add_edge('A', 'B', weight=4)
G.add_edge('B', 'C', weight=2)
G.add_edge('C', 'D', weight=1)
G.add_edge('D', 'E', weight=3)
G.add_edge('E', 'A', weight=5)

# %%
def draw_graph(graph):
    pos = nx.spring_layout(graph)
    nx.draw(graph, pos, with_labels=True, node_color='lightblue', node_size=500)
    labels = nx.get_edge_attributes(graph, 'weight')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=labels)

    plt.show()

# %%
draw_graph(G)

# %%
def draw_graph(graph, node_color):
    pos = nx.spring_layout(graph)
    nx.draw(graph, pos, with_labels=True, node_color= node_color, node_size=500)
    labels = nx.get_edge_attributes(graph, 'weight')
    nx.draw_networkx_edge_labels(graph, pos, edge_labels=labels)

    plt.show()

# %%
draw_graph(G, "red")
